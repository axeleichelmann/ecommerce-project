# %% [markdown]
# # Notebook containing code to test the API

# %%
import requests
import pandas as pd

# %%
API_url = "https://product-recs-api-50293729231.europe-west10.run.app"

# %%
# Carry out health check
response = requests.get(url=API_url + '/')
print(response.status_code)
response.json()
# Out:
# 200
# {'health_check': 'OK'}

# %%
# Carry out info check
response1 = requests.get(url=API_url + '/info')
print(response1.status_code)
response1.json()
# Out:
# 200
# {'name': 'Product Recommendation',
#  'Description': 'Search API to identify similar products to a customers previous purchases'}

# %%
# Test getting recommended products
params = {"customer_id": 2}
response2 = requests.get(url=API_url + '/recommend_products', params=params)
print(response2.status_code)
pd.DataFrame(response2.json())
# Out:
#       id       cost     category  \
# 0     98  21.714571  Tops & Tees
# 1    162  20.084261  Tops & Tees
# 2    222  14.982660  Tops & Tees
# 3    228  18.897540  Tops & Tees
# 4    235  23.354161  Tops & Tees
# 5  13636  40.524901  Accessories
# 6  13976  31.263841  Accessories
# 7  14175  31.263841  Accessories
# 8  14250  20.412540  Accessories
# 9  15286  53.721472         Plus
#
#                                                 name  brand  retail_price  \
# 0  Patty Women Cowl Neck Button Embellished Ruche...  Patty     39.990002
# 1  Patty Women Smart V Neck Ruched Long Sleeve Bl...  Patty     34.990002
# 2  Patty Women Fitted One shoulder Ruched Arm Lon...  Patty     28.980000
# 3  Patty Women Fabulous Plunge Ruched Long Sleeve...  Patty     32.980000
# 4  Patty Women Long Sleeves Ruched Turtleneck Tun...  Patty     39.990002
# 5        HOBO  Women's Rachel Vintage VI-3356 Wallet   HOBO    103.910004
# ...

# %%
# Test upcoming shopper prediction function
response3 = requests.get(url=API_url + '/upcoming_shoppers')
print(response3.status_code)
pd.DataFrame(response3.json())
# Out:
# 200
#          id first_name  last_name                         email  age gender  \
# 0      3151     Ronald      Lewis       ronaldlewis@example.net   43      M
# 1     80581      Brian       Ward         brianward@example.net   44      M
# 2     57155     Daniel     Barron      danielbarron@example.com   55      M
# 3     82826    Stephen    Collins    stephencollins@example.org   17      M
# 4     64305     Cheryl  Mcconnell   cherylmcconnell@example.com   28      F
# ...     ...        ...        ...                           ...  ...    ...
# 2323  21575      Grace     Nguyen       gracenguyen@example.net   55      F
# 2324  99803  Christine    Bonilla  christinebonilla@example.com   55      F
# 2325  57188      Amber      White        amberwhite@example.com   22      F
# 2326  86284       Gina     Hooper        ginahooper@example.com   24      F
# 2327   9138      Lacey      Woods        laceywoods@example.com   19      F
#
# ...
